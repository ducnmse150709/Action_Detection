# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
from matplotlib import image as img

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

import os
import random
from PIL import Image
import sys
from tqdm.notebook import tqdm
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
from keras import layers
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator

# %%
# Reading the csv file into a dataframe

df = pd.read_csv('./Human Action Recognition/Training_set.csv')
df
# Out:
#               filename               label
# 0          Image_1.jpg             sitting
# 1          Image_2.jpg        using_laptop
# 2          Image_3.jpg             hugging
# 3          Image_4.jpg            sleeping
# 4          Image_5.jpg        using_laptop
# ...                ...                 ...
# 12595  Image_12596.jpg             sitting
# 12596  Image_12597.jpg            clapping
# 12597  Image_12598.jpg             sitting
# 12598  Image_12599.jpg             dancing
# 12599  Image_12600.jpg  listening_to_music
#
# [12600 rows x 2 columns]

# %%
# Checking the data types

df.dtypes
# Out:
# filename    object
# label       object
# dtype: object

# %%
# Checking for null values

df.isnull().sum()
# Out:
# filename    0
# label       0
# dtype: int64

# %%
# Checking label counts

counts = df['label'].value_counts()
counts
# Out:
# sitting               840
# using_laptop          840
# hugging               840
# sleeping              840
# drinking              840
# clapping              840
# dancing               840
# cycling               840
# calling               840
# laughing              840
# eating                840
# fighting              840
# listening_to_music    840
# running               840
# texting               840
# Name: label, dtype: int64

# %%
# Function to display few random images

def displayRandom(n=1):
    plt.figure(figsize=(20,20))
    for i in range(n):
        rnd = random.randint(0,len(df)-1)
        img_file = './Human Action Recognition/train/' + df['filename'][rnd]

        if os.path.exists(img_file):
            plt.subplot(n//2+1, 2, i + 1)
            image = img.imread(img_file)
            plt.imshow(image)
            plt.title(df['label'][rnd])

# %%
# Displaying 4 random images with corresponding label

displayRandom(4)

# %%
# Label encoding and seperate dependant variable

lb = LabelBinarizer()
y = lb.fit_transform(df['label'])
classes = lb.classes_
print(classes)
# Out:
# ['calling' 'clapping' 'cycling' 'dancing' 'drinking' 'eating' 'fighting'
#  'hugging' 'laughing' 'listening_to_music' 'running' 'sitting' 'sleeping'
#  'texting' 'using_laptop']

# %%
# Take independant variable as numpy array

x = df['filename'].values

# %%
# Split data as 90% of training and 10% of test data

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=100)

# %%
# Load pixel data as a list of numpy arrays

img_data = []
size = len(x_train)

for i in tqdm(range(size)):
    image = Image.open('./Human Action Recognition/train/' + x_train[i])
    img_data.append(np.asarray(image.resize((160,160))))
# Out:
#   0%|          | 0/11340 [00:00<?, ?it/s]

# %%
# Creating the model 

model = Sequential()

pretrained_model= tf.keras.applications.VGG16(include_top=False,
                   input_shape=(160,160,3),
                   pooling='avg',classes=15,
                   weights='imagenet')

for layer in pretrained_model.layers:
        layer.trainable=False

model.add(pretrained_model)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(15, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  dense_1 (Dense)             (None, 15)                7695
#
# =================================================================
# Total params: 14,985,039
# Trainable params: 270,351
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Training the model

history = model.fit(np.asarray(img_data), y_train, epochs=60)
# Out:
# Epoch 1/60
# 355/355 [==============================] - 543s 2s/step - loss: 2.3208 - accuracy: 0.4343
# Epoch 2/60
# 355/355 [==============================] - 553s 2s/step - loss: 1.2223 - accuracy: 0.6060
# Epoch 3/60
# 355/355 [==============================] - 567s 2s/step - loss: 0.9427 - accuracy: 0.6888
# Epoch 4/60
# 355/355 [==============================] - 563s 2s/step - loss: 0.7161 - accuracy: 0.7650
# Epoch 5/60
# 355/355 [==============================] - 573s 2s/step - loss: 0.5265 - accuracy: 0.8296
# Epoch 6/60
# 355/355 [==============================] - 570s 2s/step - loss: 0.3700 - accuracy: 0.8791
# Epoch 7/60
# 355/355 [==============================] - 567s 2s/step - loss: 0.2641 - accuracy: 0.9172
# Epoch 8/60
# 355/355 [==============================] - 571s 2s/step - loss: 0.1819 - accuracy: 0.9457
# Epoch 9/60
# 355/355 [==============================] - 581s 2s/step - loss: 0.1375 - accuracy: 0.9624
# Epoch 10/60
# 355/355 [==============================] - 577s 2s/step - loss: 0.1127 - accuracy: 0.9668
# Epoch 11/60
# 110/355 [========>.....................] - ETA: 6:46 - loss: 0.1029 - accuracy: 0.9696

# %%
# Saving the model weights

model.save_weights("model.h5")

# %%
# Accuracy graph

accu = history.history['accuracy']
plt.plot(accu)

# %%
# Losses graph

losss = history.history['loss']
plt.plot(losss)

# %%
# Model accuracy

test_img_data = []
size = len(x_test)

for i in tqdm(range(size)):
    image = Image.open('./Human Action Recognition/train/' + x_test[i])
    test_img_data.append(np.asarray(image.resize((160,160))))

scores = model.evaluate(np.asarray(test_img_data), y_test)
print(f"Test Accuracy: {scores[1]}")

# %%
# Function to read images as array

def read_image(fn):
    image = Image.open(fn)
    return np.asarray(image.resize((160,160)))

# %%
# Function to predict

def test_predict(test_image):
    result = model.predict(np.asarray([read_image(test_image)]))

    itemindex = np.where(result==np.max(result))
    prediction = classes[itemindex[1][0]]
    print("probability: "+str(np.max(result)*100) + "%\nPredicted class : ", prediction)

    image = img.imread(test_image)
    plt.imshow(image)
    plt.title(prediction)

# %%
test_predict('./Human Action Recognition/test/Image_152.jpg')

# %%
test_predict('./Human Action Recognition/test/Image_3305.jpg')
# Out:
# 1/1 [==============================] - 0s 64ms/step
# probability: 99.99922513961792%
# Predicted class :  laughing
